# %% [markdown]
# <a href="https://colab.research.google.com/github/HengYuh/git/blob/main/%20graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
# %cd /content/drive/MyDrive/CompoundE-main_111
import pandas as pd
# Out:
# /content/drive/MyDrive/CompoundE-main_111

# %%
os.makedirs(os.path.join('..','data'),exist_ok=True)
data_file = os.path.join('..','data','house_tiny.csv')
with open(data_file,'w') as f:
  f.write('NumRooms,Alley,price\n')  #列名
  f.write('NA.PAVE,127500\n')
  f.write('2,NA,1006000\n')
  f.write('4,NA,178100\n')
  f.write('NA,NA,1400000\n')

# %%
data = pd.read_csv(data_file)
print(data)
# Out:
#   NumRooms     Alley      price
# 0  NA.PAVE  127500.0        NaN
# 1        2       NaN  1006000.0
# 2        4       NaN   178100.0
# 3      NaN       NaN  1400000.0

# %%
import matplotlib.pyplot as plt

# Define the data for the x-axis (Embedding Dimension) and y-axis (MRR) for each model
embedding_dimensions = [90, 120, 150, 210,240,300 ]  # Add 0 for the starting point
MRR_CompRod = [ 0.619318, 0.648917, 0.668782, 0.674608,0.673088, 0.669949]  # Replace with your actual data
MRR_CompoundE = [ 0.642260, 0.647637, 0.643857,0.64 ,0.634020,0.595275]      # Replace with your actual data
MRR_RotateE = [ 0.15, 0.35,0.35,0.36,0.35,0.35] # Replace with your actual data
MRR_TransE = [0.05, 0.35,0.35,0.36,0.35,0.35]  # Replace with your actual data


# Create the plot
plt.figure(figsize=(10,7 ))  # Set the figure size
plt.plot(embedding_dimensions, MRR_CompRod, 'r-s', label='CompRod')  # Red line with square markers
plt.plot(embedding_dimensions, MRR_CompoundE, 'b-o', label='compoundE')        # Blue line with circle markers
plt.plot(embedding_dimensions, MRR_RotateE, 'y-^', label='RotateE')      # Yellow line with triangle markers
plt.plot(embedding_dimensions, MRR_TransE, 'm-x', label='TransE')        # Magenta line with x markers

# Add title and axis labels
plt.title('MRR vs Embedding Dimension')
plt.xlabel('Embedding Dimension')
plt.ylabel('MRR')

# Add a legend
plt.legend()

# Show grid
plt.grid(True)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the data for the x-axis (Embedding Dimension) and y-axis (MRR) for each model
embedding_dimensions = [90, 120, 150, 210,240,300 ]  # Add 0 for the starting point
Hits1_CompRod = [  0.548384, 0.580731, 0.598834, 0.604326,0.602150,  0.598978]  # Replace with your actual data
Hits1_CompoundE = [0.575306, 0.580789, 0.574782 ,0.567156,0.54,0.531632]      # Replace with your actual data
Hits1_RotateE = [ 0.15, 0.35,0.35,0.36,0.35,0.35] # Replace with your actual data
Hits1_TransE = [0.05, 0.35,0.35,0.36,0.35,0.35]  # Replace with your actual data


# Create the plot
plt.figure(figsize=(10,7 ))  # Set the figure size
plt.plot(embedding_dimensions, Hits1_CompRod, 'r-s', label='CompRod')  # Red line with square markers
plt.plot(embedding_dimensions, Hits1_CompoundE, 'b-o', label='CompoundE')        # Blue line with circle markers
plt.plot(embedding_dimensions, Hits1_RotateE, 'y-^', label='RotateE')      # Yellow line with triangle markers
plt.plot(embedding_dimensions, Hits1_TransE, 'm-x', label='TransE')        # Magenta line with x markers

# Add title and axis labels
plt.title('Hits1 vs Embedding Dimension')
plt.xlabel('Embedding Dimension')
plt.ylabel('Hits1')

# Add a legend
plt.legend()

# Show grid
plt.grid(True)

# Display the plot
plt.show()

# %%
import re
import os

# Define the directory path that contains your files
directory_path = []  # Replace with the path to your files
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/R3DTSF-60-90-120-210-240-300/R3DTSF_head_and_tail_n=90_learingrate3_tnr_batch=8192")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/R3DTSF-60-90-120-210-240-300/R3DTSF_head_and_tail_n=120_learingrate3_tnr_batch=8192")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/R3DTSF-60-90-120-210-240-300/R3DTSF_head_and_tail_n=150_learingrate3_tnr_batch=8192")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/R3DTSF-60-90-120-210-240-300/R3DTSF_head_and_tail_n=180_learingrate3_tnr_batch=8192")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/R3DTSF-60-90-120-210-240-300/R3DTSF_head_and_tail_n=210_learingrate3_tnr_batch=8192")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/R3DTSF-60-90-120-210-240-300/R3DTSF_head_and_tail_n=240_learingrate3_tnr_batch=8192")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/R3DTSF-60-90-120-210-240-300/R3DTSF_head_and_tail_n=270_learingrate3_tnr_batch=8192")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/R3DTSF-60-90-120-210-240-300/R3DTSF_head_and_tail_n=300_learingrate3_tnr_batch=8192")


# Initialize lists to hold the extracted data
CompERod_hits_at_1_list = []
CompERod_hits_at_3_list = []
CompERod_hits_at_10_list = []
CompERod_mrr_list = []

# Define a regular expression pattern to extract the desired metrics
patterns = {
    'hits_at_1': re.compile(r"Test hits@1_list at step 299999: ([0-9.]+)"),
    'hits_at_3': re.compile(r"Test hits@3_list at step 299999: ([0-9.]+)"),
    'hits_at_10': re.compile(r"Test hits@10_list at step 299999: ([0-9.]+)"),
    'mrr': re.compile(r"Test mrr_list at step 299999: ([0-9.]+)")
}
# Iterate over each file in the directory
for filename in directory_path:
  with open(filename, 'r', encoding='utf-8') as file:
      text = file.read()
      for key, pattern in patterns.items():
          regex = re.compile(pattern)
          match = regex.search(text)
          if match:
              if key == 'hits_at_1':
                  CompERod_hits_at_1_list.append(float(match.group(1)))
              elif key == 'hits_at_3':
                  CompERod_hits_at_3_list.append(float(match.group(1)))
              elif key == 'hits_at_10':
                  CompERod_hits_at_10_list.append(float(match.group(1)))
              elif key == 'mrr':
                  CompERod_mrr_list.append(float(match.group(1)))

# Print the results
print("hits@1_list:", CompERod_hits_at_1_list)
print("hits@3_list:", CompERod_hits_at_3_list)
print("hits@10_list:", CompERod_hits_at_10_list)
print("mrr_list:", CompERod_mrr_list)
# Out:
# hits@1_list: [0.548384, 0.580731, 0.598834, 0.604975, 0.604326, 0.60215, 0.604459, 0.598978]
# hits@3_list: [0.647632, 0.676984, 0.697974, 0.707654, 0.705608, 0.704999, 0.707423, 0.699948]
# hits@10_list: [0.762704, 0.786979, 0.811976, 0.820073, 0.815773, 0.814836, 0.816316, 0.815387]
# mrr_list: [0.619318, 0.648917, 0.668782, 0.676181, 0.674608, 0.673088, 0.675117, 0.669949]

# %%
import re
import os

# Define the directory path that contains your files
directory_path = []  # Replace with the path to your files
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/withoutmodify-60-90-180-240-150，270，210，100，300，120/CompoundE_without_modify_tail_n=90_learingrate5_tr_batch=4096")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/withoutmodify-60-90-180-240-150，270，210，100，300，120/CompoundE_without_modify_tail_n=120_learingrate5_tr_batch=4096")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/withoutmodify-60-90-180-240-150，270，210，100，300，120/CompoundE_without_modify_tail_n=150_learingrate5_tr_batch=4096")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/withoutmodify-60-90-180-240-150，270，210，100，300，120/CompoundE_without_modify_tail_n=180_learingrate5_tr_batch=4096")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/withoutmodify-60-90-180-240-150，270，210，100，300，120/CompoundE_without_modify_tail_n=210_learingrate5_tr_batch=4096")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/withoutmodify-60-90-180-240-150，270，210，100，300，120/CompoundE_without_modify_tail_n=240_learingrate5_tr_batch=4096")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/withoutmodify-60-90-180-240-150，270，210，100，300，120/CompoundE_without_modify_tail_n=270_learingrate5_tr_batch=4096")
directory_path.append("/content/drive/MyDrive/CompoundE_main_modify_after/log/withoutmodify-60-90-180-240-150，270，210，100，300，120/CompoundE_without_modify_tail_n=300_learingrate5_tr_batch=4096")


# Initialize lists to hold the extracted data
CompoundE_hits_at_1_list = []
CompoundE_hits_at_3_list = []
CompoundE_hits_at_10_list = []
CompoundE_mrr_list = []

# Define a regular expression pattern to extract the desired metrics
patterns = {
    'hits_at_1': re.compile(r"Test hits@1_list at step 299999: ([0-9.]+)"),
    'hits_at_3': re.compile(r"Test hits@3_list at step 299999: ([0-9.]+)"),
    'hits_at_10': re.compile(r"Test hits@10_list at step 299999: ([0-9.]+)"),
    'mrr': re.compile(r"Test mrr_list at step 299999: ([0-9.]+)")
}
# Iterate over each file in the directory
for filename in directory_path:
  with open(filename, 'r', encoding='utf-8') as file:
      text = file.read()
      for key, pattern in patterns.items():
          regex = re.compile(pattern)
          match = regex.search(text)
          if match:
              if key == 'hits_at_1':
                  CompoundE_hits_at_1_list.append(float(match.group(1)))
              elif key == 'hits_at_3':
                  CompoundE_hits_at_3_list.append(float(match.group(1)))
              elif key == 'hits_at_10':
                  CompoundE_hits_at_10_list.append(float(match.group(1)))
              elif key == 'mrr':
                  CompoundE_mrr_list.append(float(match.group(1)))

# Print the results
print("hits@1_list:", CompoundE_hits_at_1_list)
print("hits@3_list:", CompoundE_hits_at_3_list)
print("hits@10_list:", CompoundE_hits_at_10_list)
print("mrr_list:", CompoundE_mrr_list)
# Out:
# hits@1_list: [0.575306, 0.580789, 0.574782, 0.571894, 0.567156, 0.560081, 0.550624, 0.531632]
# hits@3_list: [0.667876, 0.672985, 0.667975, 0.662964, 0.657639, 0.649663, 0.638991, 0.614618]
# hits@10_list: [0.778469, 0.784178, 0.779824, 0.775471, 0.771137, 0.760447, 0.748324, 0.72228]
# mrr_list: [0.64226, 0.647637, 0.643875, 0.63867, 0.63402, 0.626354, 0.616367, 0.595275]

# %%
import matplotlib.pyplot as plt
embedding_dimensions = [90,120,150,180,210,240,270,300 ]  # Add 0 for the starting point
plt.figure(figsize=(10,7 ))  # Set the figure size
plt.plot(embedding_dimensions, CompERod_mrr_list, 'r-s', label='CompRod')  # Red line with square markers
plt.plot(embedding_dimensions, CompoundE_mrr_list, 'b-o', label='compoundE')        # Blue line with circle markers
MRR_RotateE = [ 0.15, 0.35,0.35,0.36,0.35,0.35,0.35,0.35] # Replace with your actual data
MRR_TransE = [0.05, 0.35,0.35,0.36,0.35,0.35,0.35,0.35]  # Replace with your actual data
plt.plot(embedding_dimensions, MRR_RotateE, 'y-^', label='RotateE')      # Yellow line with triangle markers
plt.plot(embedding_dimensions, MRR_TransE, 'm-x', label='TransE')        # Magenta line with x markers

# Add title and axis labels
plt.title('MRR vs Embedding Dimension')
plt.xlabel('Embedding Dimension')
plt.ylabel('MRR')

# Add a legend
plt.legend()

# Show grid
plt.grid(True)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Your data goes here
embedding_dimensions = [90, 120, 150, 180, 210, 240, 270, 300]
CompERod_mrr_list = [0.619318, 0.648917, 0.668782, 0.676181, 0.674608, 0.673088, 0.675117, 0.669949]
CompoundE_mrr_list = [0.64226, 0.647637, 0.643875, 0.63867, 0.63402, 0.626354, 0.616367, 0.595275]
MRR_RotateE = [0.15, 0.35, 0.35, 0.36, 0.35, 0.35, 0.35, 0.35]
MRR_TransE = [0.05, 0.35, 0.35, 0.36, 0.35, 0.35, 0.35, 0.35]

plt.figure(figsize=(10,7))  # Set the figure size
plt.plot(embedding_dimensions, CompERod_mrr_list, 'r-s', label='CompRod')  # Red line with square markers
plt.plot(embedding_dimensions, CompoundE_mrr_list, 'b-o', label='compoundE')  # Blue line with circle markers
plt.plot(embedding_dimensions, MRR_RotateE, 'y-^', label='RotateE')  # Yellow line with triangle markers
plt.plot(embedding_dimensions, MRR_TransE, 'm-x', label='TransE')  # Magenta line with x markers

# Loop through each point to add text annotation
for dimension, mrr in zip(embedding_dimensions, CompERod_mrr_list):
    plt.text(dimension, mrr, f'{mrr:.3f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, CompoundE_mrr_list):
    plt.text(dimension, mrr, f'{mrr:.3f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, MRR_RotateE):
    plt.text(dimension, mrr, f'{mrr:.2f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, MRR_TransE):
    plt.text(dimension, mrr, f'{mrr:.2f}', ha='center', va='bottom')

# Add title and axis labels
plt.title('MRR vs Embedding Dimension')
plt.xlabel('Embedding Dimension')
plt.ylabel('MRR')

# Add a legend
plt.legend()

# Show grid
plt.grid(True)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
embedding_dimensions = [90,120,150,180,210,240,270,300 ]  # Add 0 for the starting point
plt.figure(figsize=(10,7 ))  # Set the figure size
plt.plot(embedding_dimensions, CompERod_hits_at_1_list, 'r-s', label='CompRod')  # Red line with square markers
plt.plot(embedding_dimensions, CompoundE_hits_at_1_list, 'b-o', label='compoundE')        # Blue line with circle markers
MRR_RotateE = [ 0.15, 0.35,0.35,0.36,0.35,0.35,0.35,0.35] # Replace with your actual data
MRR_TransE = [0.05, 0.35,0.35,0.36,0.35,0.35,0.35,0.35]  # Replace with your actual data
plt.plot(embedding_dimensions, MRR_RotateE, 'y-^', label='RotateE')      # Yellow line with triangle markers
plt.plot(embedding_dimensions, MRR_TransE, 'm-x', label='TransE')        # Magenta line with x markers

plt.title('Hits_1 vs Embedding Dimension')
plt.xlabel('Embedding Dimension')
plt.ylabel('Hits_1')
# Add title and axis labels
# Loop through each point to add text annotation
for dimension, mrr in zip(embedding_dimensions, CompERod_hits_at_1_list):
    plt.text(dimension, mrr, f'{mrr:.3f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, CompoundE_hits_at_1_list):
    plt.text(dimension, mrr, f'{mrr:.3f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, MRR_RotateE):
    plt.text(dimension, mrr, f'{mrr:.2f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, MRR_TransE):
    plt.text(dimension, mrr, f'{mrr:.2f}', ha='center', va='bottom')

# Add a legend
plt.legend()

# Show grid
plt.grid(True)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
embedding_dimensions = [90,120,150,180,210,240,270,300 ]  # Add 0 for the starting point
plt.figure(figsize=(10,7 ))  # Set the figure size
plt.plot(embedding_dimensions, CompERod_hits_at_3_list, 'r-s', label='CompRod')  # Red line with square markers
plt.plot(embedding_dimensions, CompoundE_hits_at_3_list, 'b-o', label='compoundE')        # Blue line with circle markers
MRR_RotateE = [0.15,0.35,0.35,0.36,0.35,0.35,0.35,0.35] # Replace with your actual data
MRR_TransE = [0.05, 0.35,0.35,0.36,0.35,0.35,0.35,0.35]  # Replace with your actual data
plt.plot(embedding_dimensions, MRR_RotateE, 'y-^', label='RotateE')      # Yellow line with triangle markers
plt.plot(embedding_dimensions, MRR_TransE, 'm-x', label='TransE')        # Magenta line with x markers

# Add title and axis labels
plt.title('Hits_3 vs Embedding Dimension')
plt.xlabel('Embedding Dimension')
plt.ylabel('Hits_3')

for dimension, mrr in zip(embedding_dimensions, CompERod_hits_at_3_list):
    plt.text(dimension, mrr, f'{mrr:.3f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, CompoundE_hits_at_3_list):
    plt.text(dimension, mrr, f'{mrr:.3f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, MRR_RotateE):
    plt.text(dimension, mrr, f'{mrr:.2f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, MRR_TransE):
    plt.text(dimension, mrr, f'{mrr:.2f}', ha='center', va='bottom')
# Add a legend
plt.legend()

# Show grid
plt.grid(True)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
embedding_dimensions = [90,120,150,180,210,240,270,300 ]  # Add 0 for the starting point
plt.figure(figsize=(10,7 ))  # Set the figure size
plt.plot(embedding_dimensions, CompERod_hits_at_10_list, 'r-s', label='CompRod')  # Red line with square markers
plt.plot(embedding_dimensions, CompoundE_hits_at_10_list, 'b-o', label='compoundE')        # Blue line with circle markers
MRR_RotateE = [ 0.15, 0.35,0.35,0.36,0.35,0.35,0.35,0.35] # Replace with your actual data
MRR_TransE = [0.05, 0.35,0.35,0.36,0.35,0.35,0.35,0.35]  # Replace with your actual data
plt.plot(embedding_dimensions, MRR_RotateE, 'y-^', label='RotateE')      # Yellow line with triangle markers
plt.plot(embedding_dimensions, MRR_TransE, 'm-x', label='TransE')        # Magenta line with x markers

# Add title and axis labels
plt.title('Hits_10 vs Embedding Dimension')
plt.xlabel('Embedding Dimension')
plt.ylabel('Hits_10')
for dimension, mrr in zip(embedding_dimensions, CompERod_hits_at_10_list):
    plt.text(dimension, mrr, f'{mrr:.3f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, CompoundE_hits_at_10_list):
    plt.text(dimension, mrr, f'{mrr:.3f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, MRR_RotateE):
    plt.text(dimension, mrr, f'{mrr:.2f}', ha='center', va='bottom')

for dimension, mrr in zip(embedding_dimensions, MRR_TransE):
    plt.text(dimension, mrr, f'{mrr:.2f}', ha='center', va='bottom')
# Add a legend
plt.legend()

# Show grid
plt.grid(True)

# Display the plot
plt.show()
